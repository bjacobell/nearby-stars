# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import blimpy as bl
import glob
import os
# %matplotlib inline

plt.rcParams['font.family'] = 'serif'
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

# %%
# get all spliced files

df = pd.read_csv('/datax/scratch/benjb/bl_nearby_stars/BL_cadences_unique_nearby_star_sample_only.csv')
df
# Out:
#        Target          RA        DEC  Distance (pc)  Cadence ID Cadence Type  \
# 0      GJ1002   0 6 42.9   -7 32 51            4.69        3635       ABACAD
# 1      GJ1002   0 6 42.9   -7 32 51            4.69        9642       ABACAD
# 2      GJ1002   0 6 42.9   -7 32 51            4.69       12847       ABACAD
# 3      GJ1002   0 6 42.9   -7 32 51            4.69      423617       ABACAD
# 4      GJ1002   0 6 42.9   -7 32 51            4.69      423617       ABACAD
# ...       ...         ...        ...            ...         ...          ...
# 39172  SO0253  2 53 4.68   16 51 52            3.85      421558       ABACAD
# 39173  SO0253  2 53 4.68   16 51 52            3.85      421558       ABACAD
# 39174  SO0253  2 53 4.68   16 51 52            3.85      421558       ABACAD
# 39175  SO0253  2 53 4.68   16 51 52            3.85      421558       ABACAD
# 39176  SO0253  2 53 4.68   16 51 52            3.85      421558       ABACAD
#
#            Receiver  Vmag Spectral Type  \
# ...

# %%
all_h5s = np.concatenate([
    df['.h5 path 1'].values,
    df['.h5 path 2'].values,
    df['.h5 path 3'].values,
    df['.h5 path 4'].values,
    df['.h5 path 5'].values,
    df['.h5 path 6'].values
])
all_h5s_unique = np.unique(all_h5s)
print(len(all_h5s_unique))
all_unique_spliced_h5s = []
for h5 in all_h5s_unique:
    if 'spliced' in h5:
        all_unique_spliced_h5s.append(h5)
all_unique_spliced_h5s = np.array(all_unique_spliced_h5s)
print(len(all_unique_spliced_h5s))
# Out:
# 231909
# 24571

# %%
console = f'bldice -f {file} -b {f_start} -e {f_stop} -x .h5 -o {output_file} -l 10'
os.system(console)
