# %%
import numpy as np 
import matplotlib.pyplot as plt 
import blimpy as bl 
import pandas as pd 
# %matplotlib inline # this line ensures plots show up in the notebook when you call plt.show()

# %%
a = np.random.random(10)
b = np.random.random(10)

print(a)
print(b)
# Out:
# [0.00540952 0.47117869 0.06740928 0.00270662 0.62647914 0.10997378
#  0.4245933  0.54236712 0.07406078 0.01261349]
# [0.66070672 0.35970446 0.54881371 0.98929977 0.94479128 0.16443015
#  0.75786746 0.39920207 0.41773985 0.21627528]

# %%
plt.scatter(a, b)
plt.show()

# %%
df = pd.read_csv('/home/cgchoza/galaxies/complete_cadences_catalog.csv')
print(df['.h5 path'].values[0])
print(df['.h5 path'].values[1024])
df
# Out:
# /datag/pipeline/AGBT18A_999_103/collate/spliced_blc0001020304050607_guppi_58306_31766_DDO210_0002.gpuspec.0000.h5
# /datag/pipeline/AGBT18B_999_89/blc37_blp07/blc37_guppi_58483_79737_IC1613_0124.gpuspec.0000.h5
#         Target          Session Band  Cadence ID  Frequency  \
# 0       DDO210  AGBT18A_999_103    L       24777       2251
# 1       DDO210  AGBT18A_999_103    L       24777       2251
# 2       DDO210  AGBT18A_999_103    L       24777       2251
# 3       DDO210  AGBT18A_999_103    L       24777       2251
# 4       DDO210  AGBT18A_999_103    L       24777       2251
# ...        ...              ...  ...         ...        ...
# 36553  NGC3226   AGBT22B_999_25    L      411390       1126
# 36554  NGC3226   AGBT22B_999_25    L      411390       1126
# 36555  NGC3226   AGBT22B_999_25    L      411390       1126
# 36556  NGC3226   AGBT22B_999_25    L      411390       1126
# 36557  NGC3226   AGBT22B_999_25    L      411390       1126
#
# ...

# %%
h5file = '/datag/pipeline/AGBT18B_999_89/blc34_blp04/blc34_guppi_58483_79737_IC1613_0124.gpuspec.0000.h5'

# %%
print(h5file)
# Out:
# /datag/pipeline/AGBT18B_999_89/blc34_blp04/blc34_guppi_58483_79737_IC1613_0124.gpuspec.0000.h5

# %%
fb = bl.Waterfall(h5file, load_data=False)
fb.info()
# Out:
# --- File Info ---
# DIMENSION_LABELS : [b'time' b'feed_id' b'frequency']
#         az_start :                              0.0
#        data_type :                                1
#             fch1 :            2401.464842353016 MHz
#             foff :      -2.7939677238464355e-06 MHz
#            ibeam :                                1
#       machine_id :                               20
#           nbeams :                                1
#            nbits :                               32
#           nchans :                         67108864
#             nifs :                                1
#      rawdatafile : guppi_58483_79737_IC1613_0124.0000.raw
#      source_name :                           IC1613
#          src_dej :                       2:08:00.96
#          src_raj :                      1:04:47.496
#     telescope_id :                                6
#            tsamp :                     18.253611008
#    tstart (ISOT) :          2018-12-31T22:08:57.000
# ...

# %%
fb = bl.Waterfall(h5file, f_start=2390, f_stop=2401.4)
fb.plot_waterfall()

# %%
fb.plot_waterfall(f_start=2399.9998, f_stop=2400.0002)

# %%
data = np.squeeze(fb.data)
print(data.shape)
# Out:
# (16, 4080219)

# %%
plt.imshow(np.log10(data), aspect='auto', interpolation='none', extent=[])
plt.show()
