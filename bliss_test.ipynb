# %%
import numpy as np 
import os
import sys
sys.path.append("/home/benjb/bliss/build/bliss/python")
import blissdedrift as bliss
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: nanobind: type 'ndarray' was already registered!
#
# <frozen importlib._bootstrap>:241: RuntimeWarning: nanobind: type 'ndarray_slice' was already registered!
#
# <frozen importlib._bootstrap>:241: RuntimeWarning: nanobind: type 'dev' was already registered!
#
# <frozen importlib._bootstrap>:241: RuntimeWarning: nanobind: type 'datatype' was already registered!

# %%
file = '/datax/scratch/benjb/bliss_LSCX_test/quick_test/widths_to_10_blc73_guppi_58832_16209_MESSIER031_0057.rawspec.0000.h5'
outdir = '/datax/scratch/benjb/bliss_LSCX_test/quick_test/'

# %%
console = 'bliss_generate_channelizer_response -f 1048576 -N 12 -M 64 -o ' + outdir + 'GBT_spliced_PFB_response_187_MHz.f32'
os.system(console)
# Out:
# Found a usable device
# Found a usable device
# Found a usable device
# Found a usable device
# 0

# %%
2**19
# Out:
# 524288

# %%
snr_list = np.arange(start=5, stop=36)
snr = 30
l1 = 10
console = 'bliss_find_hits ' + file + f' -e /datax/scratch/benjb/bliss_LSCX_test/quick_test/GBT_spliced_PFB_response_187_MHz.f32 --nodesmear -d cuda:3 -md -4 -MD 4 -s {snr} --number-coarse 64 --nchan-per-coarse 1048576 --sigmaclip-iters 5 --sigmaclip-low 3 --sigmaclip-high 4 --sk-low 0.25 --sk-high 50 --distance {l1} --output ' + outdir + os.path.basename(file)[:-3] + f'_SNR_{snr}_L1_{l1}.hits'
os.system(console)
console = 'bliss_hits_to_dat -i ' + outdir + os.path.basename(file)[:-3] + f'_SNR_{snr}_L1_{l1}.hits -o ' + outdir + os.path.basename(file)[:-3] + f'_SNR_{snr}_L1_{l1}_nodesmear.dat'
os.system(console)
# Out:
# Found a usable device
# Found a usable device
# Found a usable device
# Found a usable device
# INFO: HDF5 looking for filter plugins in:
# 	'/usr/lib/x86_64-linux-gnu/hdf5/serial/plugin'
# INFO: Got source name MESSIER031
# INFO: using cuda:3 :: NVIDIA RTX A4000 (UUID: 5b4ea69b79c6ecb6de06d81fbceef58a)
# INFO: Searching 784.0000000000001 drift rates from -4.000068250487697 Hz/sec to 4.000068250487697 Hz/sec in increments of 0.010204255741040042 Hz/sec
# INFO: Searching 784.0000000000001 drift rates from -4.000068250487697 Hz/sec to 4.000068250487697 Hz/sec in increments of 0.010204255741040042 Hz/sec
# INFO: Searching 784.0000000000001 drift rates from -4.000068250487697 Hz/sec to 4.000068250487697 Hz/sec in increments of 0.010204255741040042 Hz/sec
# INFO: Searching 784.0000000000001 drift rates from -4.000068250487697 Hz/sec to 4.000068250487697 Hz/sec in increments of 0.010204255741040042 Hz/sec
# ...

# %%
#console = 'bliss_hits_to_dat -i ' + outdir + os.path.basename(file)[:-3] + '.hits -o ' + outdir + os.path.basename(file)[:-3] + '.dat'
#os.system(console)
# Out:
# Found a usable device
# Found a usable device
# Found a usable device
# Found a usable device
# WARN: writing to file /datax/scratch/benjb/bliss_voyager_test/injections/synthetic_data_10_injections.0000.dat that already exists. Existing contents will be overwritten.
# 0
