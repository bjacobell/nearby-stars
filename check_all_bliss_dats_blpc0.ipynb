# %%
import bldw
import numpy as np
import blimpy as bl
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import setigen as stg
from astropy import units as u
# %matplotlib inline

plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"
# Out:
# numexpr.utils   INFO     Note: NumExpr detected 40 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# numexpr.utils   INFO     NumExpr defaulting to 8 threads.

# %%
dirstring = '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/*.dat'

ivec = []

count_empty = 0
for i, file in enumerate(glob.iglob(dirstring)):
    if i%100000 == 0:
        print(i)
    size_bytes = os.path.getsize(file)
    if size_bytes==0:
        print('found empty')
        count_empty += 1
    index = os.path.basename(file).split('_')[0]
    ivec.append(index)

# filename starts with {index}_{h5idx}_{k}

# k is the coarse channel number
# Out:
# 0
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 100000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 200000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 300000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 400000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 500000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 600000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 700000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 800000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 900000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1000000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1100000
# found empty
# 1200000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1300000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1400000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1500000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1600000
# 1700000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1800000
# found empty
# found empty
# found empty
# 1900000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2000000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2100000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2200000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2300000
# found empty
# 2400000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2500000
# found empty
# 2600000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2700000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2800000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 2900000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3000000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3100000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3200000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3300000
# found empty
# found empty
# found empty
# found empty
# 3400000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3500000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3600000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3700000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3800000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 3900000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 4000000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 4100000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 4200000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 4300000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# ...
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 6300000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 6400000
# found empty
# 6500000
# found empty
# 6600000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 6700000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 6800000

# %%
print(count_empty/len(ivec))
print(count_empty, len(ivec))
# Out:
# 0.0011974111459486317
# 8146 6803010

# %%
# dirstring = '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_pooled_090825/*.dat'

# ivec2 = []

# for i, file in enumerate(glob.iglob(dirstring)):
#     if i%100000 == 0:
#         print(i)
#     index = os.path.basename(file).split('_')[0]
#     ivec2.append(index)

# # filename starts with {index}_{h5idx}_{k}

# # k is the coarse channel number
# Out:
# 0
# 100000

# %%
u = np.sort(np.unique(ivec).astype(int))
# u2 = np.sort(np.unique(ivec2).astype(int))

# %%
np.savez('/datax/scratch/benjb/bl_nearby_stars/blpc0_spliced_files_idx_092925.npz', u)

# %%
print(len(u))
# Out:
# 1485

# %%
print(list(u))
#print(list(u2))
# Out:
# [204, 205, 206, 207, 214, 215, 216, 223, 224, 248, 249, 296, 303, 304, 305, 335, 336, 337, 338, 363, 364, 365, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 429, 462, 463, 517, 518, 519, 520, 643, 644, 645, 646, 647, 648, 730, 731, 732, 733, 734, 735, 787, 788, 789, 790, 791, 792, 816, 817, 818, 819, 820, 821, 822, 823, 876, 877, 878, 902, 903, 904, 905, 958, 959, 960, 961, 962, 963, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1030, 1031, 1032, 1033, 1034, 1036, 1037, 1038, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1213, 1214, 1245, 1246, 1247, 1249, 1250, 1251, 1252, 1305, 1306, 1307, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1396, 1397, 1398, 1422, 1423, 1470, 1471, 1472, 1473, 1526, 1527, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1643, 1644, 1645, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1668, 1669, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1760, 1761, 1762, 1763, 1787, 1788, 1789, 1790, 1791, 1792, 1816, 1817, 1818, 1819, 1820, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 
    for dat in list_of_dats:
        spl = os.path.basename(dat).split('_')
        cadvec.append(spl[0])
        scanvec.append(spl[1])
        ccvec.append(spl[2])
    ccvec = np.array(ccvec).astype('int')
    cadi = np.unique(cadvec)
    scani = np.unique(scanvec)
    if len(cadi) > 1:
        print(f'Too many cadence indices: {cadi}')
    if len(scani) > 1:
        print(f'Too many scan indices: {scani}')
    if np.isin(np.arange(len(ccvec)), ccvec).all():
        print(f'{cadi}: All coarse channels accounted for!')
    else:
        print(f'{cadi}: Missing coarse channels:', ccvec[~np.isin(np.arange(len(ccvec)), ccvec)])
    ### write header
    size_list = np.array([os.path.getsize(file) for file in list_of_dats])
    print(size_list)
    print(len(size_list))
    # CHECK #5412: WHAT'S UNUSUAL ABOUT THIS H5 FILE?: packet loss
    if len(np.where(size_list > 0)[0]) > 0:
        j = np.where(size_list > 0)[0][0]
        with open(list_of_dats[j]) as f:
            print(list_of_dats[j])
            header = [next(f) for _ in range(9)]
        with open(f'/datax/scratch/benjb/bl_nearby_stars/respliced_dats_from_100525/{os.path.basename(list_of_dats[0])}', 'w') as f:
            for hline in header:
                f.write(hline)
        ### write hits
        for j in range(len(list_of_dats)):
            with open(list_of_dats[j]) as f:
                all_lines = f.readlines()
                if len(all_lines) > 0:
                    lines = all_lines[9:]
                else:
                    lines = []
            with open(f'/datax/scratch/benjb/bl_nearby_stars/respliced_dats_from_100525/{os.path.basename(list_of_dats[0])}', 'a') as f:
                for line in lines:
                    f.write(line)

# %%
for i, ui in enumerate(u):
    if ui < 5412:
        continue
    cadfiles = glob.glob(f'/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/{ui}_*.dat')
    print(np.sort(np.array(cadfiles)))
    ulen = len(str(ui)) # number of digits in index
    #print(len(files))
    for j in range(6):
        print(ui, j)
        # go through all files and put the ones from, e.g., scan 1 into a separate list
        scanfiles = []
        for cadfile in cadfiles:
            if int(os.path.basename(cadfile)[ulen+1])-1 == j:
                scanfiles.append(cadfile)
        scanfiles = np.sort(np.array(scanfiles))
        # write new function to put all hits into new dat file
        print(scanfiles)
        combine_hits(scanfiles)
        #print(scanfiles[-1])
        #break
    #break
# Out:
# ['/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_1000_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_1001_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  ...
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_999_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_99_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_9_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat']
# 5412 0
# ['/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_1000_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_1001_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  ...
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_999_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_99_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_9_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat']
# ['5412']: All coarse channels accounted for!
# [772 668 668 ... 668 668 668]
# 1452
# /datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_1_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_56882_HIP113829_0032.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# 5412 1
# ['/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_2_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57227_HIP113124_0033.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_2_1000_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57227_HIP113124_0033.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_2_1001_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57227_HIP113124_0033.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  ...
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_2_999_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57227_HIP113124_0033.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_2_99_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57227_HIP113124_0033.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_2_9_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57227_HIP113124_0033.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat']
# ['5412']: All coarse channels accounted for!
# [773 669 669 ... 669 669 669]
# 1452
# /datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_2_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57227_HIP113124_0033.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# 5412 2
# ['/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_3_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57571_HIP113829_0034.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_3_1000_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57571_HIP113829_0034.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_3_1001_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57571_HIP113829_0034.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  ...
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_3_999_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57571_HIP113829_0034.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_3_99_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57571_HIP113829_0034.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_3_9_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57571_HIP113829_0034.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat']
# ['5412']: All coarse channels accounted for!
# [773 669 669 ... 669 773 669]
# 1452
# /datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_3_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57571_HIP113829_0034.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# 5412 3
# ['/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_4_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57915_HIP113336_0035.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_4_1000_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57915_HIP113336_0035.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_4_1001_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57915_HIP113336_0035.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  ...
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_4_999_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57915_HIP113336_0035.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_4_99_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57915_HIP113336_0035.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_4_9_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57915_HIP113336_0035.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat']
# ['5412']: All coarse channels accounted for!
# [769 664 664 ... 664 769 664]
# 1452
# /datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_4_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_57915_HIP113336_0035.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# 5412 4
# ['/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_5_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58259_HIP113829_0036.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_5_1000_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58259_HIP113829_0036.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_5_1001_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58259_HIP113829_0036.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  ...
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_5_999_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58259_HIP113829_0036.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_5_99_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58259_HIP113829_0036.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_5_9_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58259_HIP113829_0036.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat']
# ['5412']: All coarse channels accounted for!
# [771 668 668 ... 668 772 668]
# 1452
# /datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_5_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58259_HIP113829_0036.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# 5412 5
# ['/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_0_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_1000_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_1001_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  ...
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_999_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_99_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat'
#  '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_new_spliced_100525/5412_6_9_spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58231_58600_HIP113384_0037.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat']
# ['5412']: All coarse channels accounted for!
# [0 0 0 ... 0 0 0]
# 1452
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-a6199c3ee07f> in <module>
#      16         # write new function to put all hits into new dat file
#      17         print(scanfiles)
# ---> 18         combine_hits(scanfiles)
#      19         #print(scanfiles[-1])
#      20         #break
#
# <ipython-input-13-255a87a8fd72> in combine_hits(list_of_dats)
#      24     print(len(size_list))
#      25     # CHECK #5412: WHAT'S UNUSUAL ABOUT THIS H5 FILE?
# ---> 26     j = np.where(size_list > 0)[0][0]
#      27     with open(list_of_dats[j]) as f:
#      28         print(list_of_dats[j])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# check unspliced dats -- needs to be done separately for each blpc{0,1,2,3}
# check spliced dats -- currently doing for blpc2, needs to be done for blpc{0,1,3}
# merge all spliced dats -- currently doing for blpc2, needs to be done for blpc{0,1,3}
# pool dats together on a single blpc machine (likely blpc2)
# update CSV
# read off hits and make plots!
# start FindEvent

# figure out ad hoc plotting code for large turboSETI event counts (plot_large_dat_files.ipynb)
