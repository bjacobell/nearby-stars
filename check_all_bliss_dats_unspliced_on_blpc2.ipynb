# %%
import bldw
import numpy as np
import blimpy as bl
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import setigen as stg
from astropy import units as u
# %matplotlib inline

plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"
# Out:
# numexpr.utils   INFO     Note: NumExpr detected 40 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# numexpr.utils   INFO     NumExpr defaulting to 8 threads.

# %%
dirstring = '/datax/scratch/benjb/bl_nearby_stars/test_060226/*.dat'

ivec = []

count_empty = 0
for i, file in enumerate(glob.iglob(dirstring)):
    if i%100000 == 0:
        print(i)
    size_bytes = os.path.getsize(file)
    if size_bytes==0:
        print('found empty')
        count_empty += 1
    index = os.path.basename(file).split('_')[0]
    ivec.append(index)

# filename starts with {index}_{h5idx}_{k}

# k is the coarse channel number
# Out:
# 0
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 100000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# ...
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1100000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1200000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# 1300000
# 1400000
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty
# found empty

# %%
print(count_empty/len(ivec))
print(count_empty, len(ivec))
# Out:
# 0.007359775817309807
# 10705 1454528

# %%
# dirstring = '/datax/scratch/benjb/bl_nearby_stars/bliss_dats_pooled_090825/*.dat'

# ivec2 = []

# for i, file in enumerate(glob.iglob(dirstring)):
#     if i%100000 == 0:
#         print(i)
#     index = os.path.basename(file).split('_')[0]
#     ivec2.append(index)

# # filename starts with {index}_{h5idx}_{k}

# # k is the coarse channel number
# Out:
# 0
# 100000

# %%
u = np.sort(np.unique(ivec).astype(int))
# u2 = np.sort(np.unique(ivec2).astype(int))

# %%
# np.savez('/datax/scratch/benjb/bl_nearby_stars/blpc2_spliced_files_idx_092925.npz', u)

# %%
print(len(u))
# Out:
# 4346

# %%
print(list(u))
#print(list(u2))
# Out:
# [30, 37, 148, 152, 153, 185, 189, 190, 191, 195, 196, 266, 270, 271, 354, 517, 523, 628, 753, 947, 952, 1090, 1094, 1095, 1449, 1455, 1456, 1457, 1511, 1513, 1595, 1596, 1899, 1900, 1904, 1905, 1906, 1977, 1978, 1983, 1984, 2040, 2045, 3298, 3299, 3302, 3303, 3304, 3305, 3333, 3555, 3562, 3563, 3564, 3566, 3567, 3568, 3569, 3589, 3590, 3733, 3737, 3738, 3846, 3987, 3988, 3993, 3994, 3995, 4048, 4052, 4053, 4316, 4317, 4318, 4319, 4320, 4321, 4322, 4323, 4324, 4325, 4326, 4327, 4328, 4329, 4330, 4331, 4332, 4333, 4334, 4335, 4336, 4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344, 4345, 4346, 4347, 4348, 4349, 4350, 4351, 4352, 4353, 4354, 4355, 4356, 4357, 4358, 4359, 4360, 4361, 4362, 4363, 4364, 4365, 4366, 4367, 4368, 4369, 4370, 4371, 4372, 4373, 4374, 4375, 4376, 4377, 4378, 4379, 4380, 4381, 4382, 4383, 4384, 4385, 4386, 4387, 4388, 4389, 4390, 4391, 4392, 4393, 4394, 4395, 4396, 4397, 4398, 4399, 4400, 4401, 4402, 4403, 4404, 4405, 4406, 4407, 4408, 4409, 4410, 4411, 4412, 4413, 4414, 4415, 4416, 4417, 4418, 4419, 4420, 4421, 4422, 4423, 4424, 4425, 4426, 4427, 4428, 4429, 4430, 4431, 4432, 4433, 4434, 4435, 4436, 4437, 4438, 4439, 4440, 4441, 4442, 4443, 4444, 4445, 4446, 4447, 4448, 4449, 4450, 4451, 4452, 4453, 4454, 4460, 4461, 4462, 4463, 4464, 4465, 4466, 4467, 4468, 4469, 4470, 4471, 4472, 4473, 4474, 4475, 4476, 4477, 4478, 4479, 4480, 4481, 4482, 4483, 4484, 4485, 4486, 4487, 4488, 4489, 4490, 4491, 4492, 4493, 4494, 4495, 4496, 4497, 4498, 4499, 4500, 4501, 4502, 4503, 4504, 4505, 4506, 4507, 4508, 4509, 4510, 4511, 4512, 4513, 4514, 4515, 4516, 4517, 4518, 4519, 4520, 4521, 4522, 4523, 4524, 4525, 4526, 4527, 4528, 4529, 4530, 4531, 4532, 4533, 4534, 4535, 4536, 4537, 4538, 4539, 4540, 4541, 4542, 4543, 4544, 4545, 4546, 4547, 4548, 4549, 4550, 4551, 4552, 4553, 4554, 4555, 4556, 4557, 4558, 4559, 4560, 4561, 4562, 4563, 4564, 4565, 4566, 4567, 4568, 4569, 4570, 4571, 4572, 4573, 4574, 4575, 4576, 4577, 4578, 4579, 5075, 5799, 6200, 6204, 6205, 6291, 6295, 6296, 6297, 6301, 6302, 6356, 6575, 6579, 6580, 6634, 6955, 6961, 6962, 6963, 6965, 6966, 6967, 7316, 7320, 7321, 7451, 7452, 7456, 7457, 7458, 7464, 7469, 7516, 7541, 7591, 7731, 7737, 7738, 7739, 7742, 7743, 7744, 7745, 7775, 7779, 7780, 7857, 7861, 7862, 7922, 7923, 7927, 7928, 7929, 8050, 8051, 8089, 8171, 8172, 8175, 8176, 8177, 8232, 8233, 8236, 8237, 8238, 8300, 8301, 8305, 8306, 8307, 8375, 8379, 8380, 8381, 8761, 8819, 8853, 8854, 8855, 8858, 8859, 8860, 9013, 9017, 9018, 9159, 9165, 9166, 9167, 9298, 9305, 9306, 9311, 9312, 9510, 9514, 9515, 9686, 9687, 9688, 9770, 9771, 9775, 9776, 9777, 10053, 10054, 10364, 10365, 10368, 10369, 10370, 10371, 10374, 10375, 10376, 10623, 10670, 10679, 10806, 10807, 10810, 10811, 10812, 10888, 10889, 10904, 10905, 10909, 10910, 10911, 11303, 11338, 11339, 11343, 11344, 11409, 11410, 11411, 11414, 11415, 11416, 11417, 11419, 11420, 11669, 11745, 11746, 11749, 11750, 11751, 11833, 11868, 11872, 12112, 12162, 12163, 12191, 12192, 12195, 12196, 12197, 12324, 12333, 12450, 12520, 12521, 12524, 12525, 12526, 12527, 12566, 12570, 12571, 12663, 12664, 12667, 12668, 12669, 12750, 12751, 12755, 12756, 12838, 13167, 13168, 13169, 13171, 13172, 13173, 13174, 13239, 13240, 13241, 13242, 13243, 13244, 13438, 13443, 13986, 13987, 13988, 13991, 13992, 13993, 13994, 14018, 14019, 14022, 14023, 14024, 14025, 14231, 14232, 14233, 14235, 14236, 14237, 14238, 14239, 14375, 14376, 14377, 14378, 14380, 14381, 14382, 14383, 14413, 14414, 14417, 14418, 14419, 14502, 14746, 14770, 14875, 14882, 14883, 15108, 15161, 15162, 15163, 15164, 15165, 15166, 15167, 15168, 15169, 15196, 15198, 15199, 15200, 15201, 15202, 15203, 15204, 15281, 15286, 15450, 15451, 15452, 15455, 15456, 15457, 15643, 15649, 15650, 15651, 15654, 15655, 15656, 15657, 15712, 15713, 15789, 15794, 15993, 16034, 16038, 16039, 16249, 16331, 16332, 16333, 16334, 16335, 16336, 16337, 16338, 16339, 16370, 16374, 16375, 16478, 16479, 16480, 16482, 16483, 16484, 16485, 16532, 16771, 16 ...

# %%
def combine_hits(list_of_dats):
    cadvec = []
    scanvec = []
    ccvec = []
    for dat in list_of_dats:
        spl = os.path.basename(dat).split('_')
        cadvec.append(spl[0])
        scanvec.append(spl[1])
        ccvec.append(spl[2])
    ccvec = np.array(ccvec).astype('int')
    cadi = np.unique(cadvec)
    scani = np.unique(scanvec)
    if len(cadi) > 1:
        print(f'Too many cadence indices: {cadi}')
    if len(scani) > 1:
        print(f'Too many scan indices: {scani}')
    if np.isin(np.arange(len(ccvec)), ccvec).all():
        print(f'{cadi}: All coarse channels accounted for!')
    else:
        print(f'{cadi}: Missing coarse channels:', ccvec[~np.isin(np.arange(len(ccvec)), ccvec)])
    ### write header
    size_list = np.array([os.path.getsize(file) for file in list_of_dats])
    print(size_list)
    print(len(size_list))
    if len(np.where(size_list > 0)[0]) > 0:
        j = np.where(size_list > 0)[0][0]
        with open(list_of_dats[j]) as f:
            print(list_of_dats[j])
            header = [next(f) for _ in range(9)]
        with open(f'/datax/scratch/benjb/bl_nearby_stars/respliced_unspliced_dats/{os.path.basename(list_of_dats[0])}', 'w') as f:
            for hline in header:
                f.write(hline)
        ### write hits
        for j in range(len(list_of_dats)):
            with open(list_of_dats[j]) as f:
                all_lines = f.readlines()
                if len(all_lines) > 0:
                    lines = all_lines[9:]
                else:
                    lines = []
            with open(f'/datax/scratch/benjb/bl_nearby_stars/respliced_unspliced_dats/{os.path.basename(list_of_dats[0])}', 'a') as f:
                for line in lines:
                    f.write(line)

# %%
'''for i, ui in enumerate(u):
    # if ui < 39113:
    #     continue
    cadfiles = glob.glob(f'/datax/scratch/benjb/bl_nearby_stars/test_060226/{ui}_*.dat')
    print(np.sort(np.array(cadfiles)))
    ulen = len(str(ui)) # number of digits in index
    #print(len(files))
    for j in range(6):
        print(ui, j)
        # go through all files and put the ones from, e.g., scan 1 into a separate list
        scanfiles = []
        for cadfile in cadfiles:
            if int(os.path.basename(cadfile)[ulen+1])-1 == j:
                scanfiles.append(cadfile)
        scanfiles = np.sort(np.array(scanfiles))
        # write new function to put all hits into new dat file
        print(scanfiles)
        combine_hits(scanfiles)
        #print(scanfiles[-1])
        #break
    #break
'''
# Out:
# "for i, ui in enumerate(u):\n    # if ui < 39113:\n    #     continue\n    cadfiles = glob.glob(f'/datax/scratch/benjb/bl_nearby_stars/test_060226/{ui}_*.dat')\n    print(np.sort(np.array(cadfiles)))\n    ulen = len(str(ui)) # number of digits in index\n    #print(len(files))\n    for j in range(6):\n        print(ui, j)\n        # go through all files and put the ones from, e.g., scan 1 into a separate list\n        scanfiles = []\n        for cadfile in cadfiles:\n            if int(os.path.basename(cadfile)[ulen+1])-1 == j:\n                scanfiles.append(cadfile)\n        scanfiles = np.sort(np.array(scanfiles))\n        # write new function to put all hits into new dat file\n        print(scanfiles)\n        combine_hits(scanfiles)\n        #print(scanfiles[-1])\n        #break\n    #break\n"

# %%
df = pd.read_csv('/datax/scratch/benjb/bl_nearby_stars/BL_NSS_cadences_turboSETI_BLISS_062926.csv')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Target  \
# 0               0             0               0                 0  GJ1002
# 1               1             1               1                 1  GJ1002
# 2               2             2               2                 2  GJ1002
# 3               3             3               3                 3  GJ1002
# 4               4             4               4                 4  GJ1002
# ...           ...           ...             ...               ...     ...
# 39172       39172         39172           39172             39172  SO0253
# 39173       39173         39173           39173             39173  SO0253
# 39174       39174         39174           39174             39174  SO0253
# 39175       39175         39175           39175             39175  SO0253
# 39176       39176         39176           39176             39176  SO0253
#
#                RA        DEC  Distance (pc)  Cadence ID Cadence Type  ...  \
# 0       0 6 42.9   -7 32 51            4.69        3635       ABACAD  ...
# 1       0 6 42.9   -7 32 51            4.69        9642       ABACAD  ...
# 2       0 6 42.9   -7 32 51            4.69       12847       ABACAD  ...
# 3       0 6 42.9   -7 32 51            4.69      423617       ABACAD  ...
# 4       0 6 42.9   -7 32 51            4.69      423617       ABACAD  ...
# ...           ...        ...            ...         ...          ...  ...
# 39172  2 53 4.68   16 51 52            3.85      421558       ABACAD  ...
# 39173  2 53 4.68   16 51 52            3.85      421558       ABACAD  ...
# 39174  2 53 4.68   16 51 52            3.85      421558       ABACAD  ...
# 39175  2 53 4.68   16 51 52            3.85      421558       ABACAD  ...
# 39176  2 53 4.68   16 51 52            3.85      421558       ABACAD  ...
#
#                                              .dat path 4  \
# 0      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 1      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 2      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 3      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 4      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39173  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39174  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39175  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39176  /datax/scratch/benjb/bl_nearby_stars/seticore_...
#
#                                              .dat path 5  \
# 0      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 1      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 2      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 3      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 4      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39173  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39174  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39175  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39176  /datax/scratch/benjb/bl_nearby_stars/seticore_...
#
#                                              .dat path 6  \
# 0      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 1      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 2      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 3      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 4      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39173  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39174  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39175  /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 39176  /datax/scratch/benjb/bl_nearby_stars/seticore_...
#
#                                        bliss .dat path 1  \
# 0      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 1      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 2      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 3      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 4      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39173  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39174  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39175  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39176  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
#
#                                        bliss .dat path 2  \
# 0      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 1      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 2      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 3      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 4      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39173  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39174  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39175  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39176  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
#
#                                        bliss .dat path 3  \
# 0      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 1      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 2      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 3      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 4      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39173  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39174  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39175  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39176  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
#
#                                        bliss .dat path 4  \
# 0      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 1      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 2      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 3      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 4      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39173  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39174  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39175  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39176  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
#
#                                        bliss .dat path 5  \
# 0      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 1      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 2      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 3      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 4      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39173  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39174  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39175  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39176  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
#
#                                        bliss .dat path 6  \
# 0      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 1      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 2      /datax/scratch/benjb/bl_nearby_stars/respliced...
# 3      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 4      /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# ...                                                  ...
# 39172  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39173  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39174  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39175  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
# 39176  /datax/scratch/benjb/bl_nearby_stars/all_bliss...
#
#                                     turboSETI event .csv
# 0      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 1      /datax/scratch/benjb/bl_nearby_stars/seticore_...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39172                                                NaN
# 39173                                                NaN
# 39174                                                NaN
# 39175                                                NaN
# 39176                                                NaN
#
# [39177 rows x 38 columns]

# %%
dirstring = '/datax/scratch/benjb/bl_nearby_stars/respliced_dats_from_blpc1/*.dat'

dats = np.sort(glob.glob(dirstring))

for i, dat in enumerate(dats):
    if i%1000==0:
        print(i)
    index = os.path.basename(dat).split('_')[0]
    scani = os.path.basename(dat).split('_')[1]
    df.loc[int(index), f'bliss .dat path {scani}'] = dat
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000

# %%
bd1 = df['bliss .dat path 1'].values

print(len(bd1))
print(len(bd1[bd1.astype(str)!='nan']))
# Out:
# 39177
# 39071

# %%
df.to_csv('/datax/scratch/benjb/bl_nearby_stars/BL_NSS_cadences_turboSETI_BLISS_063026.csv')

# %%
dirstring = '/datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/*.dat'
dats = glob.iglob(dirstring)
for i, dat in enumerate(dats):
    if i > 10:
        break
    print(dat)
# Out:
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_112_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_0_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_113_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_100_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_114_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_101_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_116_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_102_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_115_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_103_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat
# /datax/scratch/benjb/bl_nearby_stars/blpc1_spliced/13168_1_117_spliced_blc0001020304050607_guppi_57835_01865_HIP28267_0014.gpuspec.0000_nosig_nosk_SNR_20_L1_30.dat

# %%
print('/datax/scratch/benjb/bl_nearby_stars/test_060226/30_4_0_blc41_guppi_60358_84814_HIP897_0050.rawspec.0000_nosig_nosk_SNR_20_L1_30.dat')
# Out:
# /datax/scratch/benjb/bl_nearby_stars/test_060226/30_4_0_blc41_guppi_60358_84814_HIP897_0050.rawspec.0000_nosig_nosk_SNR_20_L1_30.dat

# %%
# check unspliced dats -- needs to be done separately for each blpc{0,1,2,3}
# check spliced dats -- currently doing for blpc2, needs to be done for blpc{0,1,3}
# merge all spliced dats -- currently doing for blpc2, needs to be done for blpc{0,1,3}
# pool dats together on a single blpc machine (likely blpc2)
# update CSV
# read off hits and make plots!
# start FindEvent

# figure out ad hoc plotting code for large turboSETI event counts (plot_large_dat_files.ipynb)
